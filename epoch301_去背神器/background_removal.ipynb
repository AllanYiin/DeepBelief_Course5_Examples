# %%
# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt
from IPython import display

# %% [markdown]
# # 去背神器 (pytorch)

# %% [markdown]
# 支援python 版本: 3.5以上
# 支援pytorch版本 : 1.2以上

# %% [markdown]
# 對於攝影師或者是專業美工來說，去背可以說是日常進行的家常便飯，但是也正因為這個作業太頻繁也太瑣碎，所以正好成為人工智能來幫我們解決問題的好題材，除了照片修圖摳圖之外，像是直播實時更換背景，或者是可以避開人身體的彈幕，這些應用都需要將人體給分割出來。本實作將會利用谷歌的deeplab v3+來介紹如何開發去背模型。所謂的去除背景，其實目標是在預測一個逐像素的二元遮罩(binary mask)，其中，0表示是人體以外的部分，1表示是人體，在這邊服裝以及髮型也被認為是人體的一部分，髮絲級的人體分割還會涉及到matting的技術，就暫時不再本實作中討論

# %%
display.Image('../images/background_removal.jpg')

# %%
import glob
import os
import cv2
os.environ['TRIDENT_BACKEND'] = 'pytorch'

#!pip install tridentx --upgrade
import trident as T
from trident import *
from trident.models import efficientnet,deeplab
# Out:
# trident 0.4.3
# Using Pytorch backend.
# Image Data Format: channels_first.
# Image Channel Order: rgb.
# Using pillow image backend.
# Pillow version:6.2.1.
# Pytorch version:1.4.0.

# %% [markdown]
# 本次使用的數據集是吳恩達創辦的supervisely所發布的人體分割數據集Supervisely Person，在我開發的trident api中可以透過關鍵字"people"下載，裡面附的是將原圖稍作縮小的精簡版，已經足以用來訓練本次模型。若是各位對於原始數據感興趣，您也可以到 https://supervise.ly/ 即可下載取得圖資。

# %% [markdown]
# <img src="../images/supervise.png">

# %%
data_provider=load_examples_data('people')
data_provider.paired_transform_funcs=[random_center_crop(224, 224,scale=(0.7,1.3))]
data_provider.image_transform_funcs=[
                     add_noise(0.01),
                     random_adjust_gamma(gamma=(0.8,1.2)),
                     random_adjust_contrast(scale=(0.8, 1.2)),
                     normalize(0,255),
                     normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])]
# Out:
# archive file is already existing, donnot need download again.
# extraction is finished, donnot need extract again.
# get people images :5711

# %% [markdown]
# 這是一組高解析度的人體分割數據集，裡面覆蓋的場景蠻完整的，包括了正面、遠景、化妝、局部身體...都包括其中，我認為唯一的缺點就是圖片選擇有點太過唯美，因此容易過擬合，在一般照片中會效果變差，但是這可以透過數據增強技術來克服。或者是建議可以將Pascal VOC或者是之前實作範例「街景分割」的數據中的「人」的部分提取出來混合，可以讓效果變得更好

# %% [markdown]
# <img src="../images/SuperviselyPerson.jpg">

# %% [markdown]
# 原本deeplab論文中使用的是resnet以及mobilenet作為主骨幹，但是既然我們已經學到了更厲害的主骨幹EfficientNet(各位可以參考實作「鑑黃大師」)，權重數更少、執行更快且準確率越高，根本就是一次滿足三種願望，所以我們採用EfficientNetB0作為主骨幹。各位可以使用summary()來檢視他的模型結構。

# %%
backbond_net=efficientnet.EfficientNetB0(pretrained=True)
backbond_net.summary()
# Out:
# internet connect  error,model file is already existing, donnot need download again.
# C:\Anaconda3\envs\azuremlenv\lib\site-packages\torch\serialization.py:593: SourceChangeWarning: source code of class 'trident.backend.pytorch_backend.Sequential' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# C:\Anaconda3\envs\azuremlenv\lib\site-packages\torch\serialization.py:593: SourceChangeWarning: source code of class 'trident.layers.pytorch_blocks.ShortCut2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# --------------------------------------------------------------------------------------------------------------------------------
#               Layer (type)                   Output Shape            Weight           Bias    Param #     FLOPS #
# ==============================================================================
# stem.conv                                [-1, 32, 112, 112]    [32, 3, 3, 3]                  864       21663488.0
# stem.norm                                [-1, 32, 112, 112]    [32]                 [32]      64        1191680.0
# stem                                     [-1, 32, 112, 112]                                   0         0.0
# block1a.0.conv                           [-1, 32, 112, 112]    [32, 1, 3, 3]                  288       7212800.0
# block1a.0.norm                           [-1, 32, 112, 112]    [32]                 [32]      64        1191680.0
# block1a.0                                [-1, 32, 112, 112]                                   0         0.0
# block1a.1.pool                           [-1, 32]                                             0         0.0
# block1a.1.squeeze                        [-1, 8, 1, 1]         [8, 32, 1, 1]        [8]       264       519.0
# block1a.1.excite                         [-1, 32, 1, 1]        [32, 8, 1, 1]        [32]      288       543.0
# block1a.1                                [-1, 32, 112, 112]                                   0         0.0
# block1a.2.conv                           [-1, 16, 112, 112]    [16, 32, 1, 1]                 512       12832512.0
# block1a.2.norm                           [-1, 16, 112, 112]    [16]                 [16]      32        589568.0
# block1a.2                                [-1, 16, 112, 112]                                   0         0.0
# block1a.3                                [-1, 16, 112, 112]                                   0         0.0
# block1a                                  [-1, 16, 112, 112]                                   0         0.0
# block2a.0.conv                           [-1, 96, 112, 112]    [96, 16, 1, 1]                 1536      38522624.0
# block2a.0.norm                           [-1, 96, 112, 112]    [96]                 [96]      192       3600128.0
# block2a.0                                [-1, 96, 112, 112]                                   0         0.0
# block2a.1.conv                           [-1, 96, 56, 56]      [96, 1, 3, 3]                  864       5415872.0
# block2a.1.norm                           [-1, 96, 56, 56]      [96]                 [96]      192       900032.0
# block2a.1                                [-1, 96, 56, 56]                                     0         0.0
# block2a.2.pool                           [-1, 96]                                             0         0.0
# block2a.2.squeeze                        [-1, 4, 1, 1]         [4, 96, 1, 1]        [4]       388       771.0
# block2a.2.excite                         [-1, 96, 1, 1]        [96, 4, 1, 1]        [96]      480       863.0
# block2a.2                                [-1, 96, 56, 56]                                     0         0.0
# block2a.3.conv                           [-1, 24, 56, 56]      [24, 96, 1, 1]                 2304      14447552.0
# block2a.3.norm                           [-1, 24, 56, 56]      [24]                 [24]      48        222656.0
# block2a.3                                [-1, 24, 56, 56]                                     0         0.0
# block2a.4                                [-1, 24, 56, 56]                                     0         0.0
# block2a                                  [-1, 24, 56, 56]                                     0         0.0
# block2b.branch2.0.conv                   [-1, 144, 56, 56]     [144, 24, 1, 1]                3456      21672896.0
# block2b.branch2.0.norm                   [-1, 144, 56, 56]     [144]                [144]     288       1351616.0
# block2b.branch2.0                        [-1, 144, 56, 56]                                    0         0.0
# block2b.branch2.1.conv                   [-1, 144, 56, 56]     [144, 1, 3, 3]                 1296      8125376.0
# block2b.branch2.1.norm                   [-1, 144, 56, 56]     [144]                [144]     288       1351616.0
# block2b.branch2.1                        [-1, 144, 56, 56]                                    0         0.0
# block2b.branch2.2.pool                   [-1, 144]                                            0         0.0
# block2b.branch2.2.squeeze                [-1, 6, 1, 1]         [6, 144, 1, 1]       [6]       870       1733.0
# block2b.branch2.2.excite                 [-1, 144, 1, 1]       [144, 6, 1, 1]       [144]     1008      1871.0
# block2b.branch2.2                        [-1, 144, 56, 56]                                    0         0.0
# block2b.branch2.3.conv                   [-1, 24, 56, 56]      [24, 144, 1, 1]                3456      21672896.0
# block2b.branch2.3.norm                   [-1, 24, 56, 56]      [24]                 [24]      48        222656.0
# block2b.branch2.3                        [-1, 24, 56, 56]                                     0         0.0
# block2b.branch2.4                        [-1, 24, 56, 56]                                     0         0.0
# block2b.branch2                          [-1, 24, 56, 56]                                     0         0.0
# block2b                                  [-1, 24, 56, 56]                                     0         0.0
# block3a.0.conv                           [-1, 144, 56, 56]     [144, 24, 1, 1]                3456      21672896.0
# block3a.0.norm                           [-1, 144, 56, 56]     [144]                [144]     288       1351616.0
# block3a.0                                [-1, 144, 56, 56]                                    0         0.0
# block3a.1.conv                           [-1, 144, 28, 28]     [144, 1, 5, 5]                 3600      5644016.0
# block3a.1.norm                           [-1, 144, 28, 28]     [144]                [144]     288       337904.0
# block3a.1                                [-1, 144, 28, 28]                                    0         0.0
# block3a.2.pool                           [-1, 144]                                            0         0.0
# block3a.2.squeeze                        [-1, 6, 1, 1]         [6, 144, 1, 1]       [6]       870       1733.0
# block3a.2.excite                         [-1, 144, 1, 1]       [144, 6, 1, 1]       [144]     1008      1871.0
# block3a.2                                [-1, 144, 28, 28]                                    0         0.0
# block3a.3.conv                           [-1, 40, 28, 28]      [40, 144, 1, 1]                5760      9030896.0
# block3a.3.norm                           [-1, 40, 28, 28]      [40]                 [40]      80        93296.0
# block3a.3                                [-1, 40, 28, 28]                                     0         0.0
# block3a.4                                [-1, 40, 28, 28]                                     0         0.0
# block3a                                  [-1, 40, 28, 28]                                     0         0.0
# block3b.branch2.0.conv                   [-1, 240, 28, 28]     [240, 40, 1, 1]                9600      15052016.0
# block3b.branch2.0.norm                   [-1, 240, 28, 28]     [240]                [240]     480       563696.0
# block3b.branch2.0                        [-1, 240, 28, 28]                                    0         0.0
# block3b.branch2.1.conv                   [-1, 240, 28, 28]     [240, 1, 5, 5]                 6000      9407216.0
# block3b.branch2.1.norm                   [-1, 240, 28, 28]     [240]                [240]     480       563696.0
# block3b.branch2.1                        [-1, 240, 28, 28]                                    0         0.0
# block3b.branch2.2.pool                   [-1, 240]                                            0         0.0
# block3b.branch2.2.squeeze                [-1, 10, 1, 1]        [10, 240, 1, 1]      [10]      2410      4809.0
# block3b.branch2.2.excite                 [-1, 240, 1, 1]       [240, 10, 1, 1]      [240]     2640      5039.0
# block3b.branch2.2                        [-1, 240, 28, 28]                                    0         0.0
# block3b.branch2.3.conv                   [-1, 40, 28, 28]      [40, 240, 1, 1]                9600      15052016.0
# block3b.branch2.3.norm                   [-1, 40, 28, 28]      [40]                 [40]      80        93296.0
# block3b.branch2.3                        [-1, 40, 28, 28]                                     0         0.0
# block3b.branch2.4                        [-1, 40, 28, 28]                                     0         0.0
# block3b.branch2                          [-1, 40, 28, 28]                                     0         0.0
# block3b                                  [-1, 40, 28, 28]                                     0         0.0
# block4a.0.conv                           [-1, 240, 28, 28]     [240, 40, 1, 1]                9600      15052016.0
# block4a.0.norm                           [-1, 240, 28, 28]     [240]                [240]     480       563696.0
# block4a.0                                [-1, 240, 28, 28]                                    0         0.0
# block4a.1.conv                           [-1, 240, 14, 14]     [240, 1, 3, 3]                 2160      846524.0
# block4a.1.norm                           [-1, 240, 14, 14]     [240]                [240]     480       140924.0
# block4a.1                                [-1, 240, 14, 14]                                    0         0.0
# block4a.2.pool                           [-1, 240]                                            0         0.0
# block4a.2.squeeze                        [-1, 10, 1, 1]        [10, 240, 1, 1]      [10]      2410      4809.0
# block4a.2.excite                         [-1, 240, 1, 1]       [240, 10, 1, 1]      [240]     2640      5039.0
# block4a.2                                [-1, 240, 14, 14]                                    0         0.0
# block4a.3.conv                           [-1, 80, 14, 14]      [80, 240, 1, 1]                19200     7526204.0
# block4a.3.norm                           [-1, 80, 14, 14]      [80]                 [80]      160       46844.0
# block4a.3                                [-1, 80, 14, 14]                                     0         0.0
# block4a.4                                [-1, 80, 14, 14]                                     0         0.0
# block4a                                  [-1, 80, 14, 14]                                     0         0.0
# block4b.branch2.0.conv                   [-1, 480, 14, 14]     [480, 80, 1, 1]                38400     15052604.0
# block4b.branch2.0.norm                   [-1, 480, 14, 14]     [480]                [480]     960       282044.0
# block4b.branch2.0                        [-1, 480, 14, 14]                                    0         0.0
# block4b.branch2.1.conv                   [-1, 480, 14, 14]     [480, 1, 3, 3]                 4320      1693244.0
# block4b.branch2.1.norm                   [-1, 480, 14, 14]     [480]                [480]     960       282044.0
# block4b.branch2.1                        [-1, 480, 14, 14]                                    0         0.0
# block4b.branch2.2.pool                   [-1, 480]                                            0         0.0
# block4b.branch2.2.squeeze                [-1, 20, 1, 1]        [20, 480, 1, 1]      [20]      9620      19219.0
# block4b.branch2.2.excite                 [-1, 480, 1, 1]       [480, 20, 1, 1]      [480]     10080     19679.0
# block4b.branch2.2                        [-1, 480, 14, 14]                                    0         0.0
# block4b.branch2.3.conv                   [-1, 80, 14, 14]      [80, 480, 1, 1]                38400     15052604.0
# block4b.branch2.3.norm                   [-1, 80, 14, 14]      [80]                 [80]      160       46844.0
# block4b.branch2.3                        [-1, 80, 14, 14]                                     0         0.0
# block4b.branch2.4                        [-1, 80, 14, 14]                                     0         0.0
# block4b.branch2                          [-1, 80, 14, 14]                                     0         0.0
# block4b                                  [-1, 80, 14, 14]                                     0         0.0
# block4c.branch2.0.conv                   [-1, 480, 14, 14]     [480, 80, 1, 1]                38400     15052604.0
# block4c.branch2.0.norm                   [-1, 480, 14, 14]     [480]                [480]     960       282044.0
# block4c.branch2.0                        [-1, 480, 14, 14]                                    0         0.0
# block4c.branch2.1.conv                   [-1, 480, 14, 14]     [480, 1, 3, 3]                 4320      1693244.0
# block4c.branch2.1.norm                   [-1, 480, 14, 14]     [480]                [480]     960       282044.0
# block4c.branch2.1                        [-1, 480, 14, 14]                                    0         0.0
# block4c.branch2.2.pool                   [-1, 480]                                            0         0.0
# block4c.branch2.2.squeeze                [-1, 20, 1, 1]        [20, 480, 1, 1]      [20]      9620      19219.0
# block4c.branch2.2.excite                 [-1, 480, 1, 1]       [480, 20, 1, 1]      [480]     10080     19679.0
# block4c.branch2.2                        [-1, 480, 14, 14]                                    0         0.0
# block4c.branch2.3.conv                   [-1, 80, 14, 14]      [80, 480, 1, 1]                38400     15052604.0
# block4c.branch2.3.norm                   [-1, 80, 14, 14]      [80]                 [80]      160       46844.0
# block4c.branch2.3                        [-1, 80, 14, 14]                                     0         0.0
# block4c.branch2.4                        [-1, 80, 14, 14]                                     0         0.0
# block4c.branch2                          [-1, 80, 14, 14]                                     0         0.0
# block4c                                  [-1, 80, 14, 14]                                     0         0.0
# block5a.0.conv                           [-1, 480, 14, 14]     [480, 80, 1, 1]                38400     15052604.0
# block5a.0.norm                           [-1, 480, 14, 14]     [480]                [480]     960       282044.0
# block5a.0                                [-1, 480, 14, 14]                                    0         0.0
# block5a.1.conv                           [-1, 480, 14, 14]     [480, 1, 5, 5]                 12000     4703804.0
# block5a.1.norm                           [-1, 480, 14, 14]     [480]                [480]     960       282044.0
# block5a.1                                [-1, 480, 14, 14]                                    0         0.0
# block5a.2.pool                           [-1, 480]                                            0         0.0
# block5a.2.squeeze                        [-1, 20, 1, 1]        [20, 480, 1, 1]      [20]      9620      19219.0
# block5a.2.excite                         [-1, 480, 1, 1]       [480, 20, 1, 1]      [480]     10080     19679.0
# block5a.2                                [-1, 480, 14, 14]                                    0         0.0
# block5a.3.conv                           [-1, 112, 14, 14]     [112, 480, 1, 1]               53760     21073724.0
# block5a.3.norm                           [-1, 112, 14, 14]     [112]                [112]     224       65660.0
# block5a.3                                [-1, 112, 14, 14]                                    0         0.0
# block5a.4                                [-1, 112, 14, 14]                                    0         0.0
# block5a                                  [-1, 112, 14, 14]                                    0         0.0
# block5b.branch2.0.conv                   [-1, 672, 14, 14]     [672, 112, 1, 1]               75264     29503292.0
# block5b.branch2.0.norm                   [-1, 672, 14, 14]     [672]                [672]     1344      394940.0
# block5b.branch2.0                        [-1, 672, 14, 14]                                    0         0.0
# block5b.branch2.1.conv                   [-1, 672, 14, 14]     [672, 1, 5, 5]                 16800     6585404.0
# block5b.branch2.1.norm                   [-1, 672, 14, 14]     [672]                [672]     1344      394940.0
# block5b.branch2.1                        [-1, 672, 14, 14]                                    0         0.0
# block5b.branch2.2.pool                   [-1, 672]                                            0         0.0
# block5b.branch2.2.squeeze                [-1, 28, 1, 1]        [28, 672, 1, 1]      [28]      18844     37659.0
# block5b.branch2.2.excite                 [-1, 672, 1, 1]       [672, 28, 1, 1]      [672]     19488     38303.0
# block5b.branch2.2                        [-1, 672, 14, 14]                                    0         0.0
# block5b.branch2.3.conv                   [-1, 112, 14, 14]     [112, 672, 1, 1]               75264     29503292.0
# block5b.branch2.3.norm                   [-1, 112, 14, 14]     [112]                [112]     224       65660.0
# block5b.branch2.3                        [-1, 112, 14, 14]                                    0         0.0
# block5b.branch2.4                        [-1, 112, 14, 14]                                    0         0.0
# block5b.branch2                          [-1, 112, 14, 14]                                    0         0.0
# block5b                                  [-1, 112, 14, 14]                                    0         0.0
# block5c.branch2.0.conv                   [-1, 672, 14, 14]     [672, 112, 1, 1]               75264     29503292.0
# block5c.branch2.0.norm                   [-1, 672, 14, 14]     [672]                [672]     1344      394940.0
# block5c.branch2.0                        [-1, 672, 14, 14]                                    0         0.0
# block5c.branch2.1.conv                   [-1, 672, 14, 14]     [672, 1, 5, 5]                 16800     6585404.0
# block5c.branch2.1.norm                   [-1, 672, 14, 14]     [672]                [672]     1344      394940.0
# block5c.branch2.1                        [-1, 672, 14, 14]                                    0         0.0
# block5c.branch2.2.pool                   [-1, 672]                                            0         0.0
# block5c.branch2.2.squeeze                [-1, 28, 1, 1]        [28, 672, 1, 1]      [28]      18844     37659.0
# block5c.branch2.2.excite                 [-1, 672, 1, 1]       [672, 28, 1, 1]      [672]     19488     38303.0
# block5c.branch2.2                        [-1, 672, 14, 14]                                    0         0.0
# block5c.branch2.3.conv                   [-1, 112, 14, 14]     [112, 672, 1, 1]               75264     29503292.0
# block5c.branch2.3.norm                   [-1, 112, 14, 14]     [112]                [112]     224       65660.0
# block5c.branch2.3                        [-1, 112, 14, 14]                                    0         0.0
# block5c.branch2.4                        [-1, 112, 14, 14]                                    0         0.0
# block5c.branch2                          [-1, 112, 14, 14]                                    0         0.0
# block5c                                  [-1, 112, 14, 14]                                    0         0.0
# block6a.0.conv                           [-1, 672, 14, 14]     [672, 112, 1, 1]               75264     29503292.0
# block6a.0.norm                           [-1, 672, 14, 14]     [672]                [672]     1344      394940.0
# block6a.0                                [-1, 672, 14, 14]                                    0         0.0
# block6a.1.conv                           [-1, 672, 7, 7]       [672, 1, 5, 5]                 16800     1646351.0
# block6a.1.norm                           [-1, 672, 7, 7]       [672]                [672]     1344      98735.0
# block6a.1                                [-1, 672, 7, 7]                                      0         0.0
# block6a.2.pool                           [-1, 672]                                            0         0.0
# block6a.2.squeeze                        [-1, 28, 1, 1]        [28, 672, 1, 1]      [28]      18844     37659.0
# block6a.2.excite                         [-1, 672, 1, 1]       [672, 28, 1, 1]      [672]     19488     38303.0
# block6a.2                                [-1, 672, 7, 7]                                      0         0.0
# block6a.3.conv                           [-1, 192, 7, 7]       [192, 672, 1, 1]               129024    12644303.0
# block6a.3.norm                           [-1, 192, 7, 7]       [192]                [192]     384       28175.0
# block6a.3                                [-1, 192, 7, 7]                                      0         0.0
# block6a.4                                [-1, 192, 7, 7]                                      0         0.0
# block6a                                  [-1, 192, 7, 7]                                      0         0.0
# block6b.branch2.0.conv                   [-1, 1152, 7, 7]      [1152, 192, 1, 1]              221184    21675983.0
# block6b.branch2.0.norm                   [-1, 1152, 7, 7]      [1152]               [1152]    2304      169295.0
# block6b.branch2.0                        [-1, 1152, 7, 7]                                     0         0.0
# block6b.branch2.1.conv                   [-1, 1152, 7, 7]      [1152, 1, 5, 5]                28800     2822351.0
# block6b.branch2.1.norm                   [-1, 1152, 7, 7]      [1152]               [1152]    2304      169295.0
# block6b.branch2.1                        [-1, 1152, 7, 7]                                     0         0.0
# block6b.branch2.2.pool                   [-1, 1152]                                           0         0.0
# block6b.branch2.2.squeeze                [-1, 48, 1, 1]        [48, 1152, 1, 1]     [48]      55344     110639.0
# block6b.branch2.2.excite                 [-1, 1152, 1, 1]      [1152, 48, 1, 1]     [1152]    56448     111743.0
# block6b.branch2.2                        [-1, 1152, 7, 7]                                     0         0.0
# block6b.branch2.3.conv                   [-1, 192, 7, 7]       [192, 1152, 1, 1]              221184    21675983.0
# block6b.branch2.3.norm                   [-1, 192, 7, 7]       [192]                [192]     384       28175.0
# block6b.branch2.3                        [-1, 192, 7, 7]                                      0         0.0
# block6b.branch2.4                        [-1, 192, 7, 7]                                      0         0.0
# block6b.branch2                          [-1, 192, 7, 7]                                      0         0.0
# block6b                                  [-1, 192, 7, 7]                                      0         0.0
# block6c.branch2.0.conv                   [-1, 1152, 7, 7]      [1152, 192, 1, 1]              221184    21675983.0
# block6c.branch2.0.norm                   [-1, 1152, 7, 7]      [1152]               [1152]    2304      169295.0
# block6c.branch2.0                        [-1, 1152, 7, 7]                                     0         0.0
# block6c.branch2.1.conv                   [-1, 1152, 7, 7]      [1152, 1, 5, 5]                28800     2822351.0
# block6c.branch2.1.norm                   [-1, 1152, 7, 7]      [1152]               [1152]    2304      169295.0
# block6c.branch2.1                        [-1, 1152, 7, 7]                                     0         0.0
# block6c.branch2.2.pool                   [-1, 1152]                                           0         0.0
# block6c.branch2.2.squeeze                [-1, 48, 1, 1]        [48, 1152, 1, 1]     [48]      55344     110639.0
# block6c.branch2.2.excite                 [-1, 1152, 1, 1]      [1152, 48, 1, 1]     [1152]    56448     111743.0
# block6c.branch2.2                        [-1, 1152, 7, 7]                                     0         0.0
# block6c.branch2.3.conv                   [-1, 192, 7, 7]       [192, 1152, 1, 1]              221184    21675983.0
# block6c.branch2.3.norm                   [-1, 192, 7, 7]       [192]                [192]     384       28175.0
# block6c.branch2.3                        [-1, 192, 7, 7]                                      0         0.0
# block6c.branch2.4                        [-1, 192, 7, 7]                                      0         0.0
# block6c.branch2                          [-1, 192, 7, 7]                                      0         0.0
# block6c                                  [-1, 192, 7, 7]                                      0         0.0
# block6d.branch2.0.conv                   [-1, 1152, 7, 7]      [1152, 192, 1, 1]              221184    21675983.0
# block6d.branch2.0.norm                   [-1, 1152, 7, 7]      [1152]               [1152]    2304      169295.0
# block6d.branch2.0                        [-1, 1152, 7, 7]                                     0         0.0
# block6d.branch2.1.conv                   [-1, 1152, 7, 7]      [1152, 1, 5, 5]                28800     2822351.0
# block6d.branch2.1.norm                   [-1, 1152, 7, 7]      [1152]               [1152]    2304      169295.0
# block6d.branch2.1                        [-1, 1152, 7, 7]                                     0         0.0
# block6d.branch2.2.pool                   [-1, 1152]                                           0         0.0
# block6d.branch2.2.squeeze                [-1, 48, 1, 1]        [48, 1152, 1, 1]     [48]      55344     110639.0
# block6d.branch2.2.excite                 [-1, 1152, 1, 1]      [1152, 48, 1, 1]     [1152]    56448     111743.0
# block6d.branch2.2                        [-1, 1152, 7, 7]                                     0         0.0
# block6d.branch2.3.conv                   [-1, 192, 7, 7]       [192, 1152, 1, 1]              221184    21675983.0
# block6d.branch2.3.norm                   [-1, 192, 7, 7]       [192]                [192]     384       28175.0
# block6d.branch2.3                        [-1, 192, 7, 7]                                      0         0.0
# block6d.branch2.4                        [-1, 192, 7, 7]                                      0         0.0
# block6d.branch2                          [-1, 192, 7, 7]                                      0         0.0
# block6d                                  [-1, 192, 7, 7]                                      0         0.0
# block7a.0.conv                           [-1, 1152, 7, 7]      [1152, 192, 1, 1]              221184    21675983.0
# block7a.0.norm                           [-1, 1152, 7, 7]      [1152]               [1152]    2304      169295.0
# block7a.0                                [-1, 1152, 7, 7]                                     0         0.0
# block7a.1.conv                           [-1, 1152, 7, 7]      [1152, 1, 3, 3]                10368     1016015.0
# block7a.1.norm                           [-1, 1152, 7, 7]      [1152]               [1152]    2304      169295.0
# block7a.1                                [-1, 1152, 7, 7]                                     0         0.0
# block7a.2.pool                           [-1, 1152]                                           0         0.0
# block7a.2.squeeze                        [-1, 48, 1, 1]        [48, 1152, 1, 1]     [48]      55344     110639.0
# block7a.2.excite                         [-1, 1152, 1, 1]      [1152, 48, 1, 1]     [1152]    56448     111743.0
# block7a.2                                [-1, 1152, 7, 7]                                     0         0.0
# block7a.3.conv                           [-1, 320, 7, 7]       [320, 1152, 1, 1]              368640    36126671.0
# block7a.3.norm                           [-1, 320, 7, 7]       [320]                [320]     640       46991.0
# block7a.3                                [-1, 320, 7, 7]                                      0         0.0
# block7a.4                                [-1, 320, 7, 7]                                      0         0.0
# block7a                                  [-1, 320, 7, 7]                                      0         0.0
# top_conv.conv                            [-1, 1280, 7, 7]      [1280, 320, 1, 1]              409600    40140751.0
# top_conv.norm                            [-1, 1280, 7, 7]      [1280]               [1280]    2560      188111.0
# top_conv                                 [-1, 1280, 7, 7]                                     0         0.0
# avg_pool                                 [-1, 1280]                                           0         0.0
# top_dropout                              [-1, 1280]                                           0         0.0
# fc                                       [-1, 1000]            [1000, 1280]         [1000]    1281000   2560999.0
# ================================================================
# Total params: 5,288,548
# Trainable params: 5,288,548
# Non-trainable params: 0
# Total MACC: 392,552,448.0
# Total FLOPs: 0.79170 GFLOPs
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 182.43
# Params size (MB): 20.17
# Estimated Total Size (MB): 203.18
# ----------------------------------------------------------------

# %% [markdown]
# <img src="../images/deeplabv3plus.png">

# %% [markdown]
# 在Deeplab v3+中的主骨幹範圍總共將原圖下採樣4次，等於是長寬縮小1/16倍，因此要將EfficientNet裁切成適合Deeplab v3+使用的話，需要能夠找到圖像長寬縮小1/16倍的主骨幹範圍。在trident API中，會自動搜索圖像長寬縮小1/4倍(224x224縮小到56x56)以及1/16(224x224縮小到14x14)之處，來作為低層級特徵(low-level features)以及連接ASPP的高階特徵使用。對應到生成的Deeplab結構分別為backbond1.x以及backbond2.x。為了節省計算量，最後下採樣的解碼器，我使用depthwise卷積來替代標準的卷積。

# %%
backbond=backbond_net.model
deeplabv3=deeplab.DeeplabV3_plus(backbond,input_shape=(3,224,224),atrous_rates=(6,12,18,24),num_filters=256,classes=2)
deeplabv3.preprocess_flow=backbond_net.preprocess_flow

# %% [markdown]
# 所有基於預訓練骨幹的模型都最好先將大部分的預訓練區域權重凍結，然後再依照訓練狀況逐步開放，因此我們將整個deeplab模型設為可訓練，然後將主骨幹部分設為不可訓練，但是backbond2的最後一層(backbond2.0.7)是開放學習的。

# %%
#deeplabv3.load_model('Models/deeplab_seg.pth.tar')
deeplabv3.model.trainable=True
deeplabv3.model.backbond1.trainable=False
deeplabv3.model.backbond2.trainable=False
deeplabv3.model.backbond2[-1].trainable=True
deeplabv3.train()
# Out:
# 2343896 parameters have set trainable
# 19090 parameters have set untrainable
# 832718 parameters have set untrainable
# 208572 parameters have set trainable

# %% [markdown]
# 在損失函數的選取部分，我們採用複合的損失函數策略。Dice loss跟F1 Score概念有點像(各位可以參考實作:鑑黃大師)，它是權衡了準確率與召回率的一個指標，它著重在各個類別層級的像素預測吻合程度。至於大家熟悉的交叉熵，則是像素層級來判斷預測機率與實際答案之差異。兩種損失混和在一起可以獲得較全面的收斂效果。其中Dice loss的好處在於收斂非常快，但是它畢竟是類別層級，所以到了訓練中後期會比較後繼無力，這時候搭配像素層級的交叉熵，正好兩者互補。
#
# 此外，也推薦使用曠視在UnitBox這篇論文所提出的IOU Loss (Iouloss=-ln(iou))，他利用對數後取負值將原本非連續不可微分的IOU轉化成連續可微分的損失函數，它直接針對IOU做優化，所以對於會發生收斂停滯這類問題時也非常有用，但由於它本身的形式，當IOU很小時它的數值會過大且不穩定，所以比較適合與其他損失函數一起搭配使用。此外實務上，如果類別間比例非常不均衡，建議還可以加入Focal Loss，來解決比例不均衡的問題。
#
# 至於在評價函數上，我們加入了像素正確率(正確預測像素數/非背景值得像素總數)以及iou(預測值與實際值交集/預測值與實際值聯集)，兩者分子的意義是一樣的，iou的分母會大一點，所以整體數值應該會略低於像素正確率。
#
# 至於學習速率方面，請不要設得太大，建議設定為1e-4上下，否則很容易發生損失函數收斂很快然後又反彈升高的狀況。使用較低的學習速率訓練，可以獲得較穩定的結果。訓練時如果有loss持續下降但是IOU沒有顯著回升的狀況，也請保持點耐心，這是正常現象，模型要訓練到一個臨界點後，IOU才會有明顯的變化。

# %%
deeplabv3.with_optimizer(optimizer='Ranger',lr=1e-4,betas=(0.7, 0.999))\
    .with_loss(DiceLoss)\
    .with_loss(CrossEntropyLoss)\
    .with_loss(IouLoss,0.5,start_epoch=3)\
    .with_loss(FocalLoss,start_epoch=5)\
    .with_metric(pixel_accuracy,name='pixel_accuracy')\
    .with_metric(iou,name='iou')\
    .with_regularizer('l2')\
    .with_constraint('max_min_norm')\
    .with_learning_rate_scheduler(reduce_lr_on_plateau,monitor='iou',mode='max',factor=0.75,patience=5,cooldown=2,threshold=1e-5,warmup=0)\
    .with_model_save_path('Models/deeplab_seg.pth')\
    .with_callbacks(SegTileImageCallback(batch_inteval=50,reverse_image_transform=data_provider.reverse_image_transform,background=(255,128,255)))

deeplabv3.summary()

#在模型中設定
#with_optimizer 設定優化器為Ranger
#with_loss(DiceLoss) 加入Dice loss損失函數(類別層級)
#with_loss(CrossEntropyLoss,2)加入交叉熵作為損失函數(像素層級)
#with_loss(IouLoss,1)加入iou損失作為損失函數(類別層級) 直接針對iou優化

#建議訓練的後半段可以加入
#with_loss(FocalLoss,2)加入FocalLoss作為損失函數(像素層級)解決類別不均衡問題

#with_metric(pixel_accuracy) 加入像素正確率metrics
#with_metric(iou,name='iou') 加入iou作為metrics
#with_regularizer('l2')\ 加入l2正則
#with_constraint('max_min_norm')\ 加入max_min_norm權重正則
#with_learning_rate_scheduler(reduce_lr_on_plateau) 加入reduce_lr_on_plateau學習率變化原則(指標不再變動時，學習率下降)
#with_model_save_path('Models/deeplab_seg.pth') 設定模型存檔路徑
#with_callbacks 加入SegTileImageCallback來繪製比較用的tile images
# Out:
# DiceLoss signature:['output', 'target']
# CrossEntropyLoss signature:['output', 'target']
# IouLoss signature:['output', 'target']
# FocalLoss signature:['output', 'target']
# pixel_accuracy signature:['output', 'target']
# iou signature:['output', 'target']
# --------------------------------------------------------------------------------------------------------------------------------
#               Layer (type)                   Output Shape            Weight           Bias    Param #     FLOPS #
# ==============================================================================
# backbond1.0.0.conv                       [-1, 32, 112, 112]    [32, 3, 3, 3]                  864       21663488.0
# backbond1.0.0.norm                       [-1, 32, 112, 112]    [32]                 [32]      64        1191680.0
# backbond1.0.0                            [-1, 32, 112, 112]                                   0         0.0
# backbond1.0.1.0.conv                     [-1, 32, 112, 112]    [32, 1, 3, 3]                  288       7212800.0
# backbond1.0.1.0.norm                     [-1, 32, 112, 112]    [32]                 [32]      64        1191680.0
# backbond1.0.1.0                          [-1, 32, 112, 112]                                   0         0.0
# backbond1.0.1.1.pool                     [-1, 32]                                             0         0.0
# backbond1.0.1.1.squeeze                  [-1, 8, 1, 1]         [8, 32, 1, 1]        [8]       264       519.0
# backbond1.0.1.1.excite                   [-1, 32, 1, 1]        [32, 8, 1, 1]        [32]      288       543.0
# backbond1.0.1.1                          [-1, 32, 112, 112]                                   0         0.0
# backbond1.0.1.2.conv                     [-1, 16, 112, 112]    [16, 32, 1, 1]                 512       12832512.0
# backbond1.0.1.2.norm                     [-1, 16, 112, 112]    [16]                 [16]      32        589568.0
# backbond1.0.1.2                          [-1, 16, 112, 112]                                   0         0.0
# backbond1.0.1.3                          [-1, 16, 112, 112]                                   0         0.0
# backbond1.0.1                            [-1, 16, 112, 112]                                   0         0.0
# backbond1.0.2.0.conv                     [-1, 96, 112, 112]    [96, 16, 1, 1]                 1536      38522624.0
# backbond1.0.2.0.norm                     [-1, 96, 112, 112]    [96]                 [96]      192       3600128.0
# backbond1.0.2.0                          [-1, 96, 112, 112]                                   0         0.0
# backbond1.0.2.1.conv                     [-1, 96, 56, 56]      [96, 1, 3, 3]                  864       5415872.0
# backbond1.0.2.1.norm                     [-1, 96, 56, 56]      [96]                 [96]      192       900032.0
# backbond1.0.2.1                          [-1, 96, 56, 56]                                     0         0.0
# backbond1.0.2.2.pool                     [-1, 96]                                             0         0.0
# backbond1.0.2.2.squeeze                  [-1, 4, 1, 1]         [4, 96, 1, 1]        [4]       388       771.0
# backbond1.0.2.2.excite                   [-1, 96, 1, 1]        [96, 4, 1, 1]        [96]      480       863.0
# backbond1.0.2.2                          [-1, 96, 56, 56]                                     0         0.0
# backbond1.0.2.3.conv                     [-1, 24, 56, 56]      [24, 96, 1, 1]                 2304      14447552.0
# backbond1.0.2.3.norm                     [-1, 24, 56, 56]      [24]                 [24]      48        222656.0
# backbond1.0.2.3                          [-1, 24, 56, 56]                                     0         0.0
# backbond1.0.2.4                          [-1, 24, 56, 56]                                     0         0.0
# backbond1.0.2                            [-1, 24, 56, 56]                                     0         0.0
# backbond1.0.3.branch2.0.conv             [-1, 144, 56, 56]     [144, 24, 1, 1]                3456      21672896.0
# backbond1.0.3.branch2.0.norm             [-1, 144, 56, 56]     [144]                [144]     288       1351616.0
# backbond1.0.3.branch2.0                  [-1, 144, 56, 56]                                    0         0.0
# backbond1.0.3.branch2.1.conv             [-1, 144, 56, 56]     [144, 1, 3, 3]                 1296      8125376.0
# backbond1.0.3.branch2.1.norm             [-1, 144, 56, 56]     [144]                [144]     288       1351616.0
# backbond1.0.3.branch2.1                  [-1, 144, 56, 56]                                    0         0.0
# backbond1.0.3.branch2.2.pool             [-1, 144]                                            0         0.0
# backbond1.0.3.branch2.2.squeeze          [-1, 6, 1, 1]         [6, 144, 1, 1]       [6]       870       1733.0
# backbond1.0.3.branch2.2.excite           [-1, 144, 1, 1]       [144, 6, 1, 1]       [144]     1008      1871.0
# backbond1.0.3.branch2.2                  [-1, 144, 56, 56]                                    0         0.0
# backbond1.0.3.branch2.3.conv             [-1, 24, 56, 56]      [24, 144, 1, 1]                3456      21672896.0
# backbond1.0.3.branch2.3.norm             [-1, 24, 56, 56]      [24]                 [24]      48        222656.0
# backbond1.0.3.branch2.3                  [-1, 24, 56, 56]                                     0         0.0
# backbond1.0.3.branch2.4                  [-1, 24, 56, 56]                                     0         0.0
# backbond1.0.3.branch2                    [-1, 24, 56, 56]                                     0         0.0
# backbond1.0.3                            [-1, 24, 56, 56]                                     0         0.0
# backbond1.0                              [-1, 24, 56, 56]                                     0         0.0
# backbond1                                [-1, 24, 56, 56]                                     0         0.0
# backbond2.0.0.0.conv                     [-1, 144, 56, 56]     [144, 24, 1, 1]                3456      21672896.0
# backbond2.0.0.0.norm                     [-1, 144, 56, 56]     [144]                [144]     288       1351616.0
# backbond2.0.0.0                          [-1, 144, 56, 56]                                    0         0.0
# backbond2.0.0.1.conv                     [-1, 144, 28, 28]     [144, 1, 5, 5]                 3600      5644016.0
# backbond2.0.0.1.norm                     [-1, 144, 28, 28]     [144]                [144]     288       337904.0
# backbond2.0.0.1                          [-1, 144, 28, 28]                                    0         0.0
# backbond2.0.0.2.pool                     [-1, 144]                                            0         0.0
# backbond2.0.0.2.squeeze                  [-1, 6, 1, 1]         [6, 144, 1, 1]       [6]       870       1733.0
# backbond2.0.0.2.excite                   [-1, 144, 1, 1]       [144, 6, 1, 1]       [144]     1008      1871.0
# backbond2.0.0.2                          [-1, 144, 28, 28]                                    0         0.0
# backbond2.0.0.3.conv                     [-1, 40, 28, 28]      [40, 144, 1, 1]                5760      9030896.0
# backbond2.0.0.3.norm                     [-1, 40, 28, 28]      [40]                 [40]      80        93296.0
# backbond2.0.0.3                          [-1, 40, 28, 28]                                     0         0.0
# backbond2.0.0.4                          [-1, 40, 28, 28]                                     0         0.0
# backbond2.0.0                            [-1, 40, 28, 28]                                     0         0.0
# backbond2.0.1.branch2.0.conv             [-1, 240, 28, 28]     [240, 40, 1, 1]                9600      15052016.0
# backbond2.0.1.branch2.0.norm             [-1, 240, 28, 28]     [240]                [240]     480       563696.0
# backbond2.0.1.branch2.0                  [-1, 240, 28, 28]                                    0         0.0
# backbond2.0.1.branch2.1.conv             [-1, 240, 28, 28]     [240, 1, 5, 5]                 6000      9407216.0
# backbond2.0.1.branch2.1.norm             [-1, 240, 28, 28]     [240]                [240]     480       563696.0
# backbond2.0.1.branch2.1                  [-1, 240, 28, 28]                                    0         0.0
# backbond2.0.1.branch2.2.pool             [-1, 240]                                            0         0.0
# backbond2.0.1.branch2.2.squeeze          [-1, 10, 1, 1]        [10, 240, 1, 1]      [10]      2410      4809.0
# backbond2.0.1.branch2.2.excite           [-1, 240, 1, 1]       [240, 10, 1, 1]      [240]     2640      5039.0
# backbond2.0.1.branch2.2                  [-1, 240, 28, 28]                                    0         0.0
# backbond2.0.1.branch2.3.conv             [-1, 40, 28, 28]      [40, 240, 1, 1]                9600      15052016.0
# backbond2.0.1.branch2.3.norm             [-1, 40, 28, 28]      [40]                 [40]      80        93296.0
# backbond2.0.1.branch2.3                  [-1, 40, 28, 28]                                     0         0.0
# backbond2.0.1.branch2.4                  [-1, 40, 28, 28]                                     0         0.0
# backbond2.0.1.branch2                    [-1, 40, 28, 28]                                     0         0.0
# backbond2.0.1                            [-1, 40, 28, 28]                                     0         0.0
# backbond2.0.2.0.conv                     [-1, 240, 28, 28]     [240, 40, 1, 1]                9600      15052016.0
# backbond2.0.2.0.norm                     [-1, 240, 28, 28]     [240]                [240]     480       563696.0
# backbond2.0.2.0                          [-1, 240, 28, 28]                                    0         0.0
# backbond2.0.2.1.conv                     [-1, 240, 14, 14]     [240, 1, 3, 3]                 2160      846524.0
# backbond2.0.2.1.norm                     [-1, 240, 14, 14]     [240]                [240]     480       140924.0
# backbond2.0.2.1                          [-1, 240, 14, 14]                                    0         0.0
# backbond2.0.2.2.pool                     [-1, 240]                                            0         0.0
# backbond2.0.2.2.squeeze                  [-1, 10, 1, 1]        [10, 240, 1, 1]      [10]      2410      4809.0
# backbond2.0.2.2.excite                   [-1, 240, 1, 1]       [240, 10, 1, 1]      [240]     2640      5039.0
# backbond2.0.2.2                          [-1, 240, 14, 14]                                    0         0.0
# backbond2.0.2.3.conv                     [-1, 80, 14, 14]      [80, 240, 1, 1]                19200     7526204.0
# backbond2.0.2.3.norm                     [-1, 80, 14, 14]      [80]                 [80]      160       46844.0
# backbond2.0.2.3                          [-1, 80, 14, 14]                                     0         0.0
# backbond2.0.2.4                          [-1, 80, 14, 14]                                     0         0.0
# backbond2.0.2                            [-1, 80, 14, 14]                                     0         0.0
# backbond2.0.3.branch2.0.conv             [-1, 480, 14, 14]     [480, 80, 1, 1]                38400     15052604.0
# backbond2.0.3.branch2.0.norm             [-1, 480, 14, 14]     [480]                [480]     960       282044.0
# backbond2.0.3.branch2.0                  [-1, 480, 14, 14]                                    0         0.0
# backbond2.0.3.branch2.1.conv             [-1, 480, 14, 14]     [480, 1, 3, 3]                 4320      1693244.0
# backbond2.0.3.branch2.1.norm             [-1, 480, 14, 14]     [480]                [480]     960       282044.0
# backbond2.0.3.branch2.1                  [-1, 480, 14, 14]                                    0         0.0
# backbond2.0.3.branch2.2.pool             [-1, 480]                                            0         0.0
# backbond2.0.3.branch2.2.squeeze          [-1, 20, 1, 1]        [20, 480, 1, 1]      [20]      9620      19219.0
# backbond2.0.3.branch2.2.excite           [-1, 480, 1, 1]       [480, 20, 1, 1]      [480]     10080     19679.0
# backbond2.0.3.branch2.2                  [-1, 480, 14, 14]                                    0         0.0
# backbond2.0.3.branch2.3.conv             [-1, 80, 14, 14]      [80, 480, 1, 1]                38400     15052604.0
# backbond2.0.3.branch2.3.norm             [-1, 80, 14, 14]      [80]                 [80]      160       46844.0
# backbond2.0.3.branch2.3                  [-1, 80, 14, 14]                                     0         0.0
# backbond2.0.3.branch2.4                  [-1, 80, 14, 14]                                     0         0.0
# backbond2.0.3.branch2                    [-1, 80, 14, 14]                                     0         0.0
# backbond2.0.3                            [-1, 80, 14, 14]                                     0         0.0
# backbond2.0.4.branch2.0.conv             [-1, 480, 14, 14]     [480, 80, 1, 1]                38400     15052604.0
# backbond2.0.4.branch2.0.norm             [-1, 480, 14, 14]     [480]                [480]     960       282044.0
# backbond2.0.4.branch2.0                  [-1, 480, 14, 14]                                    0         0.0
# backbond2.0.4.branch2.1.conv             [-1, 480, 14, 14]     [480, 1, 3, 3]                 4320      1693244.0
# backbond2.0.4.branch2.1.norm             [-1, 480, 14, 14]     [480]                [480]     960       282044.0
# backbond2.0.4.branch2.1                  [-1, 480, 14, 14]                                    0         0.0
# backbond2.0.4.branch2.2.pool             [-1, 480]                                            0         0.0
# backbond2.0.4.branch2.2.squeeze          [-1, 20, 1, 1]        [20, 480, 1, 1]      [20]      9620      19219.0
# backbond2.0.4.branch2.2.excite           [-1, 480, 1, 1]       [480, 20, 1, 1]      [480]     10080     19679.0
# backbond2.0.4.branch2.2                  [-1, 480, 14, 14]                                    0         0.0
# backbond2.0.4.branch2.3.conv             [-1, 80, 14, 14]      [80, 480, 1, 1]                38400     15052604.0
# backbond2.0.4.branch2.3.norm             [-1, 80, 14, 14]      [80]                 [80]      160       46844.0
# backbond2.0.4.branch2.3                  [-1, 80, 14, 14]                                     0         0.0
# backbond2.0.4.branch2.4                  [-1, 80, 14, 14]                                     0         0.0
# backbond2.0.4.branch2                    [-1, 80, 14, 14]                                     0         0.0
# backbond2.0.4                            [-1, 80, 14, 14]                                     0         0.0
# backbond2.0.5.0.conv                     [-1, 480, 14, 14]     [480, 80, 1, 1]                38400     15052604.0
# backbond2.0.5.0.norm                     [-1, 480, 14, 14]     [480]                [480]     960       282044.0
# backbond2.0.5.0                          [-1, 480, 14, 14]                                    0         0.0
# backbond2.0.5.1.conv                     [-1, 480, 14, 14]     [480, 1, 5, 5]                 12000     4703804.0
# backbond2.0.5.1.norm                     [-1, 480, 14, 14]     [480]                [480]     960       282044.0
# backbond2.0.5.1                          [-1, 480, 14, 14]                                    0         0.0
# backbond2.0.5.2.pool                     [-1, 480]                                            0         0.0
# backbond2.0.5.2.squeeze                  [-1, 20, 1, 1]        [20, 480, 1, 1]      [20]      9620      19219.0
# backbond2.0.5.2.excite                   [-1, 480, 1, 1]       [480, 20, 1, 1]      [480]     10080     19679.0
# backbond2.0.5.2                          [-1, 480, 14, 14]                                    0         0.0
# backbond2.0.5.3.conv                     [-1, 112, 14, 14]     [112, 480, 1, 1]               53760     21073724.0
# backbond2.0.5.3.norm                     [-1, 112, 14, 14]     [112]                [112]     224       65660.0
# backbond2.0.5.3                          [-1, 112, 14, 14]                                    0         0.0
# backbond2.0.5.4                          [-1, 112, 14, 14]                                    0         0.0
# backbond2.0.5                            [-1, 112, 14, 14]                                    0         0.0
# backbond2.0.6.branch2.0.conv             [-1, 672, 14, 14]     [672, 112, 1, 1]               75264     29503292.0
# backbond2.0.6.branch2.0.norm             [-1, 672, 14, 14]     [672]                [672]     1344      394940.0
# backbond2.0.6.branch2.0                  [-1, 672, 14, 14]                                    0         0.0
# backbond2.0.6.branch2.1.conv             [-1, 672, 14, 14]     [672, 1, 5, 5]                 16800     6585404.0
# backbond2.0.6.branch2.1.norm             [-1, 672, 14, 14]     [672]                [672]     1344      394940.0
# backbond2.0.6.branch2.1                  [-1, 672, 14, 14]                                    0         0.0
# backbond2.0.6.branch2.2.pool             [-1, 672]                                            0         0.0
# backbond2.0.6.branch2.2.squeeze          [-1, 28, 1, 1]        [28, 672, 1, 1]      [28]      18844     37659.0
# backbond2.0.6.branch2.2.excite           [-1, 672, 1, 1]       [672, 28, 1, 1]      [672]     19488     38303.0
# backbond2.0.6.branch2.2                  [-1, 672, 14, 14]                                    0         0.0
# backbond2.0.6.branch2.3.conv             [-1, 112, 14, 14]     [112, 672, 1, 1]               75264     29503292.0
# backbond2.0.6.branch2.3.norm             [-1, 112, 14, 14]     [112]                [112]     224       65660.0
# backbond2.0.6.branch2.3                  [-1, 112, 14, 14]                                    0         0.0
# backbond2.0.6.branch2.4                  [-1, 112, 14, 14]                                    0         0.0
# backbond2.0.6.branch2                    [-1, 112, 14, 14]                                    0         0.0
# backbond2.0.6                            [-1, 112, 14, 14]                                    0         0.0
# backbond2.0.7.branch2.0.conv             [-1, 672, 14, 14]     [672, 112, 1, 1]               75264     29503292.0
# backbond2.0.7.branch2.0.norm             [-1, 672, 14, 14]     [672]                [672]     1344      394940.0
# backbond2.0.7.branch2.0                  [-1, 672, 14, 14]                                    0         0.0
# backbond2.0.7.branch2.1.conv             [-1, 672, 14, 14]     [672, 1, 5, 5]                 16800     6585404.0
# backbond2.0.7.branch2.1.norm             [-1, 672, 14, 14]     [672]                [672]     1344      394940.0
# backbond2.0.7.branch2.1                  [-1, 672, 14, 14]                                    0         0.0
# backbond2.0.7.branch2.2.pool             [-1, 672]                                            0         0.0
# backbond2.0.7.branch2.2.squeeze          [-1, 28, 1, 1]        [28, 672, 1, 1]      [28]      18844     37659.0
# backbond2.0.7.branch2.2.excite           [-1, 672, 1, 1]       [672, 28, 1, 1]      [672]     19488     38303.0
# backbond2.0.7.branch2.2                  [-1, 672, 14, 14]                                    0         0.0
# backbond2.0.7.branch2.3.conv             [-1, 112, 14, 14]     [112, 672, 1, 1]               75264     29503292.0
# backbond2.0.7.branch2.3.norm             [-1, 112, 14, 14]     [112]                [112]     224       65660.0
# backbond2.0.7.branch2.3                  [-1, 112, 14, 14]                                    0         0.0
# backbond2.0.7.branch2.4                  [-1, 112, 14, 14]                                    0         0.0
# backbond2.0.7.branch2                    [-1, 112, 14, 14]                                    0         0.0
# backbond2.0.7                            [-1, 112, 14, 14]                                    0         0.0
# backbond2.0                              [-1, 112, 14, 14]                                    0         0.0
# backbond2                                [-1, 112, 14, 14]                                    0         0.0
# aspp.convs.conv1.conv                    [-1, 256, 14, 14]     [256, 112, 1, 1]               28672     11239228.0
# aspp.convs.conv1.norm                    [-1, 256, 14, 14]     [256]                [256]     512       150332.0
# aspp.convs.conv1                         [-1, 256, 14, 14]                                    0         0.0
# aspp.convs.aspp_dilation0.conv           [-1, 256, 14, 14]     [256, 112, 3, 3]               258048    101154620.0
# aspp.convs.aspp_dilation0.norm           [-1, 256, 14, 14]     [256]                [256]     512       150332.0
# aspp.convs.aspp_dilation0                [-1, 256, 14, 14]                                    0         0.0
# aspp.convs.aspp_dilation1.conv           [-1, 256, 14, 14]     [256, 112, 3, 3]               258048    101154620.0
# aspp.convs.aspp_dilation1.norm           [-1, 256, 14, 14]     [256]                [256]     512       150332.0
# aspp.convs.aspp_dilation1                [-1, 256, 14, 14]                                    0         0.0
# aspp.convs.aspp_dilation2.conv           [-1, 256, 14, 14]     [256, 112, 3, 3]               258048    101154620.0
# aspp.convs.aspp_dilation2.norm           [-1, 256, 14, 14]     [256]                [256]     512       150332.0
# aspp.convs.aspp_dilation2                [-1, 256, 14, 14]                                    0         0.0
# aspp.convs.aspp_dilation3.conv           [-1, 256, 14, 14]     [256, 112, 3, 3]               258048    101154620.0
# aspp.convs.aspp_dilation3.norm           [-1, 256, 14, 14]     [256]                [256]     512       150332.0
# aspp.convs.aspp_dilation3                [-1, 256, 14, 14]                                    0         0.0
# aspp.convs.aspp_pooling.0                [-1, 112, 1, 1]                                      0         0.0
# aspp.convs.aspp_pooling.1                [-1, 256, 1, 1]       [256, 112, 1, 1]               28672     57343.0
# aspp.convs.aspp_pooling.2                [-1, 256, 14, 14]                                    0         0.0
# aspp.convs.aspp_pooling                  [-1, 256, 14, 14]                                    0         0.0
# aspp.convs                               [-1, 1536, 14, 14]                                   0         0.0
# aspp.project.conv                        [-1, 256, 14, 14]     [256, 1536, 1, 1]              393216    154140476.0
# aspp.project.norm                        [-1, 256, 14, 14]     [256]                [256]     512       150332.0
# aspp.project                             [-1, 256, 14, 14]                                    0         0.0
# aspp                                     [-1, 256, 14, 14]                                    0         0.0
# low_level_conv.conv                      [-1, 48, 56, 56]      [48, 24, 1, 1]                 1152      7222208.0
# low_level_conv.norm                      [-1, 48, 56, 56]      [48]                 [48]      96        448448.0
# low_level_conv                           [-1, 48, 56, 56]                                     0         0.0
# decoder.0.conv                           [-1, 152, 56, 56]     [152, 2, 3, 3]                 2736      17157056.0
# decoder.0.norm                           [-1, 152, 56, 56]     [152]                [152]     304       1426880.0
# decoder.0                                [-1, 152, 56, 56]                                    0         0.0
# decoder.1.conv                           [-1, 152, 56, 56]     [152, 1, 3, 3]                 1368      8576960.0
# decoder.1.norm                           [-1, 152, 56, 56]     [152]                [152]     304       1426880.0
# decoder.1                                [-1, 152, 56, 56]                                    0         0.0
# decoder.2                                [-1, 2, 56, 56]       [2, 152, 1, 1]                 304       1903552.0
# decoder                                  [-1, 2, 56, 56]                                      0         0.0
# ================================================================
# Total params: 2,343,896
# Trainable params: 1,700,660
# Non-trainable params: 643,236
# Total MACC: 553,291,008.0
# Total FLOPs: 1.11382 GFLOPs
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 199.74
# Params size (MB): 8.94
# Estimated Total Size (MB): 209.26
# ----------------------------------------------------------------

# %%
plan=TrainingPlan()\
    .add_training_item(deeplabv3,name='deeplab')\
    .with_data_loader(data_provider)\
    .repeat_epochs(10)\
    .within_minibatch_size(12)\
    .print_progress_scheduling(10,unit='batch')\
    .display_loss_metric_curve_scheduling(frequency=100,unit='batch',imshow=True)\
    .save_model_scheduling(20,unit='batch')\

#add_training_item加入要訓練的模型
#with_data_loader加入數據提供者
#repeat_epochs設定要執行的epoch數量
#within_minibatch_size設定minibatch_size
#print_progress_scheduling設定列印進度的頻率
#display_loss_metric_curve_scheduling設定顯示損失函數曲線的頻率
#save_model_scheduling設定存檔的頻率

# %%
plan.start_now()
# Out:
# deeplab      Step: 17s392ms | Loss: 0.563   | pixel_accuracy: 89.280% ,iou: 75.041%  | learning rate: 1.000e-04 | epoch: 8  ( 400/476 )
# deeplab      Step: 17s256ms | Loss: 0.592   | pixel_accuracy: 86.312% ,iou: 73.605%  | learning rate: 1.000e-04 | epoch: 8  ( 410/476 )
# deeplab      Step: 14s475ms | Loss: 0.584   | pixel_accuracy: 86.635% ,iou: 72.712%  | learning rate: 1.000e-04 | epoch: 8  ( 420/476 )
# deeplab      Step: 14s672ms | Loss: 0.573   | pixel_accuracy: 86.786% ,iou: 76.308%  | learning rate: 1.000e-04 | epoch: 8  ( 430/476 )
# deeplab      Step: 14s437ms | Loss: 0.560   | pixel_accuracy: 89.650% ,iou: 76.111%  | learning rate: 1.000e-04 | epoch: 8  ( 440/476 )
# deeplab      Step: 14s845ms | Loss: 0.596   | pixel_accuracy: 86.827% ,iou: 71.362%  | learning rate: 1.000e-04 | epoch: 8  ( 450/476 )
# deeplab      Step: 16s163ms | Loss: 0.571   | pixel_accuracy: 88.237% ,iou: 73.965%  | learning rate: 1.000e-04 | epoch: 8  ( 460/476 )
# deeplab      Step: 14s727ms | Loss: 0.570   | pixel_accuracy: 87.984% ,iou: 75.620%  | learning rate: 1.000e-04 | epoch: 8  ( 470/476 )
# deeplab      Step: 8s560ms  | Loss: 0.570   | pixel_accuracy: 88.339% ,iou: 75.026%  | learning rate: 1.000e-04 | epoch: 9  ( 0/476 )
# OrderedDict([('total_losses', 0.5704274674256643), ('DiceLoss', 0.1027975007891655), ('CrossEntropyLoss', 0.3737247586250305), ('l2_reg_Loss', 2.510731246729847e-05), ('IouLoss', 0.07224424928426743), ('FocalLoss', 0.01016808208078146)])
# deeplab      Step: 15s851ms | Loss: 0.566   | pixel_accuracy: 88.892% ,iou: 75.844%  | learning rate: 1.000e-04 | epoch: 9  ( 10/476 )
# deeplab      Step: 14s202ms | Loss: 0.550   | pixel_accuracy: 90.424% ,iou: 74.543%  | learning rate: 1.000e-04 | epoch: 9  ( 20/476 )
# deeplab      Step: 14s421ms | Loss: 0.571   | pixel_accuracy: 87.716% ,iou: 75.042%  | learning rate: 1.000e-04 | epoch: 9  ( 30/476 )
# deeplab      Step: 14s659ms | Loss: 0.553   | pixel_accuracy: 89.146% ,iou: 77.577%  | learning rate: 1.000e-04 | epoch: 9  ( 40/476 )
# deeplab      Step: 14s822ms | Loss: 0.570   | pixel_accuracy: 86.521% ,iou: 76.292%  | learning rate: 1.000e-04 | epoch: 9  ( 50/476 )
# deeplab      Step: 16s840ms | Loss: 0.586   | pixel_accuracy: 85.903% ,iou: 74.905%  | learning rate: 1.000e-04 | epoch: 9  ( 60/476 )
# deeplab      Step: 15s165ms | Loss: 0.607   | pixel_accuracy: 85.855% ,iou: 70.569%  | learning rate: 1.000e-04 | epoch: 9  ( 70/476 )
# deeplab      Step: 14s170ms | Loss: 0.566   | pixel_accuracy: 87.832% ,iou: 76.461%  | learning rate: 1.000e-04 | epoch: 9  ( 80/476 )
# deeplab      Step: 14s526ms | Loss: 0.588   | pixel_accuracy: 88.560% ,iou: 72.838%  | learning rate: 1.000e-04 | epoch: 9  ( 90/476 )
# deeplab      Step: 16s110ms | Loss: 0.582   | pixel_accuracy: 88.801% ,iou: 72.265%  | learning rate: 1.000e-04 | epoch: 9  ( 100/476 )
# deeplab      Step: 15s868ms | Loss: 0.585   | pixel_accuracy: 86.343% ,iou: 74.370%  | learning rate: 1.000e-04 | epoch: 9  ( 110/476 )
# deeplab      Step: 14s632ms | Loss: 0.580   | pixel_accuracy: 87.336% ,iou: 73.797%  | learning rate: 1.000e-04 | epoch: 9  ( 120/476 )
# deeplab      Step: 14s289ms | Loss: 0.593   | pixel_accuracy: 84.873% ,iou: 73.535%  | learning rate: 1.000e-04 | epoch: 9  ( 130/476 )
# deeplab      Step: 13s775ms | Loss: 0.599   | pixel_accuracy: 86.221% ,iou: 70.118%  | learning rate: 1.000e-04 | epoch: 9  ( 140/476 )
# deeplab      Step: 14s88ms  | Loss: 0.603   | pixel_accuracy: 84.043% ,iou: 73.942%  | learning rate: 1.000e-04 | epoch: 9  ( 150/476 )
# deeplab      Step: 15s706ms | Loss: 0.574   | pixel_accuracy: 87.055% ,iou: 76.308%  | learning rate: 1.000e-04 | epoch: 9  ( 160/476 )
# deeplab      Step: 14s211ms | Loss: 0.568   | pixel_accuracy: 88.975% ,iou: 74.740%  | learning rate: 1.000e-04 | epoch: 9  ( 170/476 )
# deeplab      Step: 14s56ms  | Loss: 0.534   | pixel_accuracy: 89.773% ,iou: 78.259%  | learning rate: 1.000e-04 | epoch: 9  ( 180/476 )
# deeplab      Step: 19s848ms | Loss: 0.551   | pixel_accuracy: 89.534% ,iou: 75.380%  | learning rate: 1.000e-04 | epoch: 9  ( 190/476 )
# deeplab      Step: 21s267ms | Loss: 0.595   | pixel_accuracy: 86.211% ,iou: 72.992%  | learning rate: 1.000e-04 | epoch: 9  ( 200/476 )
# deeplab      Step: 15s727ms | Loss: 0.571   | pixel_accuracy: 88.006% ,iou: 75.082%  | learning rate: 1.000e-04 | epoch: 9  ( 210/476 )
# deeplab      Step: 14s563ms | Loss: 0.572   | pixel_accuracy: 89.268% ,iou: 75.089%  | learning rate: 1.000e-04 | epoch: 9  ( 220/476 )
# deeplab      Step: 14s667ms | Loss: 0.591   | pixel_accuracy: 88.076% ,iou: 72.854%  | learning rate: 1.000e-04 | epoch: 9  ( 230/476 )
# deeplab      Step: 14s430ms | Loss: 0.577   | pixel_accuracy: 87.851% ,iou: 73.273%  | learning rate: 1.000e-04 | epoch: 9  ( 240/476 )
# deeplab      Step: 14s625ms | Loss: 0.578   | pixel_accuracy: 86.900% ,iou: 74.288%  | learning rate: 1.000e-04 | epoch: 9  ( 250/476 )
# deeplab      Step: 15s489ms | Loss: 0.565   | pixel_accuracy: 87.786% ,iou: 76.243%  | learning rate: 1.000e-04 | epoch: 9  ( 260/476 )
# deeplab      Step: 14s216ms | Loss: 0.565   | pixel_accuracy: 88.110% ,iou: 77.249%  | learning rate: 1.000e-04 | epoch: 9  ( 270/476 )
# deeplab      Step: 13s988ms | Loss: 0.562   | pixel_accuracy: 88.373% ,iou: 74.638%  | learning rate: 1.000e-04 | epoch: 9  ( 280/476 )
# deeplab      Step: 14s99ms  | Loss: 0.559   | pixel_accuracy: 88.385% ,iou: 76.563%  | learning rate: 1.000e-04 | epoch: 9  ( 290/476 )
# deeplab      Step: 15s711ms | Loss: 0.583   | pixel_accuracy: 88.144% ,iou: 73.791%  | learning rate: 1.000e-04 | epoch: 9  ( 300/476 )
# deeplab      Step: 15s827ms | Loss: 0.546   | pixel_accuracy: 89.950% ,iou: 76.636%  | learning rate: 1.000e-04 | epoch: 9  ( 310/476 )
# deeplab      Step: 14s148ms | Loss: 0.575   | pixel_accuracy: 86.842% ,iou: 75.171%  | learning rate: 1.000e-04 | epoch: 9  ( 320/476 )
# deeplab      Step: 14s166ms | Loss: 0.559   | pixel_accuracy: 89.245% ,iou: 76.057%  | learning rate: 1.000e-04 | epoch: 9  ( 330/476 )
# deeplab      Step: 14s49ms  | Loss: 0.571   | pixel_accuracy: 87.414% ,iou: 75.525%  | learning rate: 1.000e-04 | epoch: 9  ( 340/476 )
# deeplab      Step: 14s576ms | Loss: 0.578   | pixel_accuracy: 86.708% ,iou: 76.276%  | learning rate: 1.000e-04 | epoch: 9  ( 350/476 )
# deeplab      Step: 15s900ms | Loss: 0.569   | pixel_accuracy: 88.982% ,iou: 75.401%  | learning rate: 1.000e-04 | epoch: 9  ( 360/476 )
# deeplab      Step: 14s394ms | Loss: 0.590   | pixel_accuracy: 85.793% ,iou: 73.328%  | learning rate: 1.000e-04 | epoch: 9  ( 370/476 )
# deeplab      Step: 14s260ms | Loss: 0.569   | pixel_accuracy: 88.232% ,iou: 74.504%  | learning rate: 1.000e-04 | epoch: 9  ( 380/476 )
# deeplab      Step: 14s470ms | Loss: 0.572   | pixel_accuracy: 87.586% ,iou: 73.430%  | learning rate: 1.000e-04 | epoch: 9  ( 390/476 )
# deeplab      Step: 15s640ms | Loss: 0.556   | pixel_accuracy: 89.411% ,iou: 75.845%  | learning rate: 1.000e-04 | epoch: 9  ( 400/476 )
# deeplab      Step: 16s31ms  | Loss: 0.584   | pixel_accuracy: 85.674% ,iou: 74.572%  | learning rate: 1.000e-04 | epoch: 9  ( 410/476 )
# deeplab      Step: 13s953ms | Loss: 0.583   | pixel_accuracy: 86.284% ,iou: 73.221%  | learning rate: 1.000e-04 | epoch: 9  ( 420/476 )
# deeplab      Step: 15s551ms | Loss: 0.544   | pixel_accuracy: 89.104% ,iou: 78.532%  | learning rate: 1.000e-04 | epoch: 9  ( 430/476 )
# deeplab      Step: 14s916ms | Loss: 0.574   | pixel_accuracy: 88.389% ,iou: 73.558%  | learning rate: 1.000e-04 | epoch: 9  ( 440/476 )
# deeplab      Step: 15s709ms | Loss: 0.604   | pixel_accuracy: 85.733% ,iou: 71.116%  | learning rate: 1.000e-04 | epoch: 9  ( 450/476 )
# deeplab      Step: 16s810ms | Loss: 0.556   | pixel_accuracy: 89.018% ,iou: 76.805%  | learning rate: 1.000e-04 | epoch: 9  ( 460/476 )
